# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
path = "../data/Test_knight.csv"
data_test = pd.read_csv(path)
data_test
# Out:
#      Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0         11.420     20.38     77.58   386.1  0.14250    0.28390    0.24140
# 1         18.250     19.98    119.60  1040.0  0.09463    0.10900    0.11270
# 2         14.680     20.13     94.74   684.5  0.09867    0.07200    0.07395
# 3         13.540     14.36     87.46   566.3  0.09779    0.08129    0.06664
# 4         15.340     14.26    102.50   704.4  0.10730    0.21350    0.20770
# ..           ...       ...       ...     ...      ...        ...        ...
# 166        9.423     27.88     59.26   271.3  0.08123    0.04971    0.00000
# 167       14.590     22.68     96.39   657.1  0.08473    0.13300    0.10290
# 168       20.920     25.09    143.00  1347.0  0.10990    0.22360    0.31740
# 169       16.600     28.08    108.30   858.1  0.08455    0.10230    0.09251
# 170        7.760     24.54     47.92   181.0  0.05263    0.04362    0.00000
#
# ...

# %%
path = "../data/Train_knight.csv"
data_train= pd.read_csv(path)
data_train
# Out:
#      Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0         11.800     17.26     75.26   431.9  0.09087    0.06232   0.028530
# 1         19.810     22.15    130.00  1260.0  0.09831    0.10270   0.147900
# 2         10.970     17.20     71.73   371.5  0.08915    0.11130   0.094570
# 3         11.620     18.18     76.38   408.8  0.11750    0.14830   0.102000
# 4         11.260     19.83     71.30   388.1  0.08511    0.04413   0.005067
# ..           ...       ...       ...     ...      ...        ...        ...
# 393        8.618     11.79     54.34   224.5  0.09752    0.05272   0.020610
# 394       13.530     10.94     87.91   559.2  0.12910    0.10470   0.068770
# 395       11.640     18.33     75.17   412.5  0.11420    0.10170   0.070700
# 396        9.876     19.40     63.95   298.3  0.10050    0.09697   0.061540
# 397       19.550     28.77    133.60  1207.0  0.09260    0.20630   0.178400
#
# ...

# %%
X = data_train

X_train, X_valid = train_test_split(X, train_size=0.8, random_state=42)	# train 80%, validation 20%
X_train
# Out:
#      Sensitivity  Hability  Strength  Power  Agility  Dexterity  Awareness  \
# 3         11.620     18.18     76.38  408.8  0.11750    0.14830    0.10200
# 18        12.250     17.94     78.27  460.3  0.08654    0.06679    0.03885
# 376       13.240     20.13     86.87  542.9  0.08284    0.12230    0.10100
# 248       11.340     18.61     72.76  391.2  0.10490    0.08499    0.04302
# 177       16.690     20.20    107.10  857.6  0.07497    0.07112    0.03649
# ..           ...       ...       ...    ...      ...        ...        ...
# 71        17.460     39.28    113.40  920.6  0.09812    0.12980    0.14170
# 106       12.540     16.32     81.25  476.3  0.11580    0.10850    0.05928
# 270        9.777     16.99     62.50  290.2  0.10370    0.08404    0.04334
# 348       16.160     21.54    106.20  809.8  0.10080    0.12840    0.10430
# 102       12.780     16.49     81.37  502.5  0.09831    0.05234    0.03653
#
# ...

# %%
X_valid
# Out:
#      Sensitivity  Hability  Strength  Power  Agility  Dexterity  Awareness  \
# 198       10.800      9.71     68.77  357.6  0.09594    0.05736    0.02531
# 396        9.876     19.40     63.95  298.3  0.10050    0.09697    0.06154
# 33        11.200     29.37     70.67  386.0  0.07449    0.03558    0.00000
# 208       11.540     10.72     73.73  409.1  0.08597    0.05969    0.01367
# 93        11.600     12.84     74.34  412.6  0.08983    0.07525    0.04196
# ..           ...       ...       ...    ...      ...        ...        ...
# 249       11.760     21.60     74.72  427.9  0.08637    0.04966    0.01657
# 225       11.300     18.19     73.93  389.4  0.09592    0.13250    0.15480
# 367       12.670     17.30     81.25  489.9  0.10280    0.07664    0.03193
# 175       16.250     19.51    109.80  815.8  0.10260    0.18930    0.22360
# 285       16.130     20.68    108.10  798.8  0.11700    0.20220    0.17220
#
# ...

# %%
df_valid = pd.DataFrame(X_valid)
df_valid.to_csv("Validation_knight.csv")

df_train = pd.DataFrame(X_train)
df_train.to_csv("Training_knight.csv")

# %% [markdown]
# The rough standard for train-validation-test splits is 60-80% training data, 10-20% validation data, and 10-20% test data.
