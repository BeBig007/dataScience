# %%
import matplotlib.pyplot as plt

import pandas as pd

# %matplotlib inline

# %%
path = "../data/Test_knight.csv"
data_test = pd.read_csv(path)

data_test.head()
# Out:
#    Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0        11.42     20.38     77.58   386.1  0.14250    0.28390    0.24140
# 1        18.25     19.98    119.60  1040.0  0.09463    0.10900    0.11270
# 2        14.68     20.13     94.74   684.5  0.09867    0.07200    0.07395
# 3        13.54     14.36     87.46   566.3  0.09779    0.08129    0.06664
# 4        15.34     14.26    102.50   704.4  0.10730    0.21350    0.20770
#
#    Prescience  Reactivity  Midi-chlorien  ...  Recovery  Evade   Stims  \
# 0     0.10520      0.2597        0.09744  ...     14.91  26.50   98.87
# 1     0.07400      0.1794        0.05742  ...     22.88  27.66  153.20
# 2     0.05259      0.1586        0.05922  ...     19.07  30.88  123.40
# 3     0.04781      0.1885        0.05766  ...     15.11  19.26   99.70
# 4     0.09756      0.2521        0.07032  ...     18.07  19.08  125.10
#
#    Sprint   Combo   Delay  Attunement  Empowered   Burst  Grasping
# ...

# %%
columns = data_test.columns
N = len(columns)

# %%
fig, axs = plt.subplots(6, 5, figsize=(20, 20))
for idx, column in enumerate(columns[:N]):
    row = idx // 5
    col = idx % 5
    axs[row, col].hist(data_test[column], bins=40, color='#7fbf7f')
    axs[row, col].set_title(column)
    axs[row, col].legend(['Knight'])
plt.tight_layout()
plt.show()

# %%
path = "../data/Train_knight.csv"
data_train= pd.read_csv(path)  

data_train.head()
# Out:
#    Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0        11.80     17.26     75.26   431.9  0.09087    0.06232   0.028530
# 1        19.81     22.15    130.00  1260.0  0.09831    0.10270   0.147900
# 2        10.97     17.20     71.73   371.5  0.08915    0.11130   0.094570
# 3        11.62     18.18     76.38   408.8  0.11750    0.14830   0.102000
# 4        11.26     19.83     71.30   388.1  0.08511    0.04413   0.005067
#
#    Prescience  Reactivity  Midi-chlorien  ...  Evade   Stims  Sprint   Combo  \
# 0    0.016380      0.1847        0.06019  ...  24.49   86.00   562.0  0.1244
# 1    0.094980      0.1582        0.05395  ...  30.88  186.80  2398.0  0.1512
# 2    0.036130      0.1489        0.06640  ...  26.87   90.14   476.4  0.1391
# 3    0.055640      0.1957        0.07255  ...  25.40   88.14   528.1  0.1780
# 4    0.005664      0.1637        0.06343  ...  26.43   76.38   435.9  0.1108
#
# ...

# %%
data_sith = data_train[data_train['knight'] == 'Sith']
data_sith.head()
# Out:
#    Sensitivity  Hability  Strength  Power  Agility  Dexterity  Awareness  \
# 0        11.80     17.26     75.26  431.9  0.09087    0.06232   0.028530
# 2        10.97     17.20     71.73  371.5  0.08915    0.11130   0.094570
# 3        11.62     18.18     76.38  408.8  0.11750    0.14830   0.102000
# 4        11.26     19.83     71.30  388.1  0.08511    0.04413   0.005067
# 9        12.70     12.17     80.88  495.0  0.08785    0.05794   0.023600
#
#    Prescience  Reactivity  Midi-chlorien  ...  Evade  Stims  Sprint   Combo  \
# 0    0.016380      0.1847        0.06019  ...  24.49  86.00   562.0  0.1244
# 2    0.036130      0.1489        0.06640  ...  26.87  90.14   476.4  0.1391
# 3    0.055640      0.1957        0.07255  ...  25.40  88.14   528.1  0.1780
# 4    0.005664      0.1637        0.06343  ...  26.43  76.38   435.9  0.1108
# 9    0.024020      0.1583        0.06275  ...  16.92  88.12   566.9  0.1314
#
#      Delay  Attunement  Empowered   Burst  Grasping  knight
# ...

# %%
data_jedi = data_train[data_train['knight'] == 'Jedi']
data_jedi.head()
# Out:
#    Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 1        19.81     22.15     130.0  1260.0  0.09831    0.10270     0.1479
# 5        18.08     21.84     117.4  1024.0  0.07371    0.08642     0.1103
# 6        15.08     25.74      98.0   716.6  0.10240    0.09769     0.1235
# 7        19.69     21.25     130.0  1203.0  0.10960    0.15990     0.1974
# 8        19.89     20.26     130.5  1214.0  0.10370    0.13100     0.1411
#
#    Prescience  Reactivity  Midi-chlorien  ...  Evade  Stims  Sprint    Combo  \
# 1     0.09498      0.1582        0.05395  ...  30.88  186.8  2398.0  0.15120
# 5     0.05778      0.1770        0.05340  ...  24.70  129.1  1228.0  0.08822
# 6     0.06553      0.1647        0.06464  ...  33.22  121.2  1050.0  0.16600
# 7     0.12790      0.2069        0.05999  ...  25.53  152.5  1709.0  0.14440
# 8     0.09431      0.1802        0.06188  ...  25.23  160.5  1646.0  0.14170
#
# ...

# %%
fig, axs = plt.subplots(6, 5, figsize=(20, 20))
for idx, column in enumerate(columns[:N]):
    row = idx // 5
    col = idx % 5
    axs[row, col].hist(data_sith[column], bins=40, color='red', alpha=0.5)
    axs[row, col].hist(data_jedi[column], bins=40, color='blue', alpha=0.5)
    axs[row, col].set_title(column)
    axs[row, col].legend(['Sith', 'Jedi'])
plt.tight_layout()
plt.show()
